# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.colors import to_rgba

# Set the display width to a larger value (e.g., 200 characters)
pd.set_option('display.width', 200)

# Allow each column to display more content without truncation
pd.set_option('colheader_justify','center','display.max_colwidth', None)

# 1.9.25 : after reviewing some of the general sentiment of ecology, it seems there is a popular index (the 
# Shannon index) that is used for biodiversity (interestingly a derivative of an entropy equation). Scrapping
# previous work in favour of pursuing this. Original work saved in different python file

# %%
# Data to be worked with
obs_df = pd.read_csv("observations.csv")
spec_df = pd.read_csv("species_info.csv")

#  double-check/clean
def initial_check(df):
    print(df.count())
    print(df.head(3))
    print(df.describe(include = "all"))
    print(df.dtypes)
    return

# commenting the checks for processing time

# initial_check(obs_df)
# initial_check(spec_df)

obs_df = obs_df.drop_duplicates()
spec_df = spec_df.drop_duplicates()

# merge dataframes into one on scientific_name column and reset the index
merged = pd.merge(obs_df, spec_df[['scientific_name','category','conservation_status']], on='scientific_name').sort_values(by='category', ascending=True).reset_index().drop(columns='index')

# easier to reference park list get rid of all ' National Park' to make it look slightly better for charts. Later dropped need for parks with exploration of data
merged['park_name'] = merged['park_name'].str.replace('National Park', '').str.strip()
merged = merged.drop_duplicates()
park_l = merged.park_name.unique()

# check work
initial_check(merged)
# Out:
# scientific_name        23301
# park_name              23301
# observations           23301
# category               23301
# conservation_status      780
# dtype: int64
#          scientific_name         park_name    observations  category  conservation_status
# 0     Gastrophryne carolinensis  Yellowstone       235      Amphibian          NaN
# 1  Desmognathus quadramaculatus  Yellowstone       255      Amphibian          NaN
# 2       Batrachoseps diabolicus     Yosemite       155      Amphibian          NaN
#        scientific_name park_name  observations     category    conservation_status
# count           23301     23301    23301.00000           23301                 780
# unique           5541         4            NaN               7                   4
# top       Canis lupus     Bryce            NaN  Vascular Plant  Species of Concern
# freq               24      5828            NaN           17867                 644
# ...

# %%
# create a Shannon index dataframe by grouping merged data by park name and taxonomic category and create three columns 
# 1) sum of observations (total number of individuals from each species observed in each park, population density)
# 2) count of conservation status (count of species of concern per taxonomic category and park)
# 3) count of unique scientific names (total number of different species to get an idea of the richness)

index_df = merged.groupby(['park_name','category']).agg(
    observation_sum = ('observations','sum'), conserv_stat_count = ('conservation_status','count'), unique_spec = ('scientific_name','nunique')).reset_index()

# Below used to create dictionary of total observations per park.

total_observations_per_park = {}
for x in park_l:
    total_observations_per_park[x] = index_df[index_df.park_name == x].observation_sum.sum()
# the .map function applies the value of the key in a dictionary to a match in a dataframe row
park_map = index_df['park_name'].map(total_observations_per_park)

# column to calculate the proportion of the population each observation of taxonomic category was
index_df['pop_proportion'] = index_df['observation_sum'] / park_map

# weighted observation sum. Went different direction, but it seems that weighted observations may be useful in other diversity measures?
# index_df['weights'] = (index_df['observation_sum'] * index_df['pop_proportion'])

# check work
test = index_df[index_df.park_name == 'Bryce']
print(test)
# Out:
#   park_name      category       observation_sum  conserv_stat_count  unique_spec  pop_proportion
# 0    Bryce           Amphibian        7380                7               79         0.012808
# 1    Bryce                Bird       51647               79              488         0.089635
# 2    Bryce                Fish       12587               12              125         0.021845
# 3    Bryce              Mammal       20680               41              176         0.035891
# 4    Bryce   Nonvascular Plant       32992                5              333         0.057258
# 5    Bryce             Reptile        7950                5               78         0.013797
# 6    Bryce      Vascular Plant      442959               46             4262         0.768766

# %%
# thank you ChatGPT for helping correctly decipher the shannon diversity index formula

# Also, it would be at this point, I'd be trying to get a lot more feedback from anyone familiar with the science in accurate calculation in conjunction with what I could
# dig up from the internet. Trust but verify and collaboration is key. I wasn't given the methodology of the study from the exercise, so working with what I have.

# Define q
q = 1  #from what I read 1 is appropriate for shannon's formula

# Function to calculate diversity for a group (or the whole dataset if no grouping)
def calculate_diversity(df, q):
    if q == 1:
        # Handle the special case for q=1 (Shannon entropy)
        diversity = (-df['pop_proportion'] * df['pop_proportion'].apply(lambda x: 0 if x == 0 else np.log(x))).sum()
        return round(np.exp(diversity),3)
    else:
        # General formula
        diversity = (df['pop_proportion']**q).sum()**(1 / (1 - q))
        return round(diversity,3)

# Calculate diversity index for the whole dataset
park_indices = {}
for x in list(index_df.park_name.unique()):
    temp = index_df[index_df.park_name == x]
    div_index = calculate_diversity(temp, q)
    park_indices[x] = div_index
park_indices_table = pd.DataFrame(park_indices, index=["Shannon Diversity Index"])
print(park_indices_table)
# Out:
#                          Bryce  Great Smoky Mountains  Yellowstone  Yosemite
# Shannon Diversity Index  2.46           2.438             2.449       2.45

# %%
# Since the indices are so close together, lets see if there is anything more telling to this data that can display actionable information or solidify normalcy

# Category list for easier reference
cat_l = list(index_df.category.unique())

# create dictionary to refine the data frame above into another with the shannon indices per taxonomic category in each park
park_cat_index_dict = {}
for x in park_l:
    temp = []
    for y in cat_l:
        temp.append(calculate_diversity(index_df[(index_df.park_name == x)&(index_df.category == y)],q))
    park_cat_index_dict[x] = temp

# Create column for category to match up all of the entries
park_cat_index_dict['category'] = cat_l

# create new dataframe, to make sure the values stay with the appropriate categories and national parks
park_cat_index_df = pd.DataFrame(park_cat_index_dict)
park_cat_index_df = park_cat_index_df[['category','Bryce','Great Smoky Mountains','Yellowstone','Yosemite']]

# sort the indices to have the lowest category first, if it turns out that there is a good bit of diversity between parks then rethink organization
park_cat_index_df = park_cat_index_df.sort_values(by='Bryce').reset_index().drop(columns='index')
print(park_cat_index_df)

# All of the categories are very close across in indices, would be easier to display them all in one bar graph instead of clusters of subplots. Temp is the list of averages
temp = []
for a in range(7):
    temp.append(np.average(list(park_cat_index_df.T[a][1:])))
for x in park_cat_index_df.keys()[1:]:
    park_cat_index_df[x] = [round(y,3) for y in park_cat_index_df[x]]
# check work
print(temp)
# Out:
#        category       Bryce  Great Smoky Mountains  Yellowstone  Yosemite
# 0          Amphibian  1.057          1.059             1.060       1.059
# 1            Reptile  1.061          1.059             1.060       1.059
# 2               Fish  1.087          1.086             1.086       1.087
# 3             Mammal  1.127          1.124             1.125       1.125
# 4  Nonvascular Plant  1.178          1.179             1.179       1.179
# 5     Vascular Plant  1.224          1.221             1.222       1.223
# 6               Bird  1.241          1.237             1.238       1.239
# [1.0587499999999999, 1.05975, 1.0865, 1.12525, 1.1787500000000002, 1.2225000000000001, 1.23875]

# %%
# Function created with the help of Chat GPT, figsize and font size values added later for ease of design readability
def create_banded_table_with_title(dataframe, title, x, y, z):
    fig, ax = plt.subplots(figsize=(x, y))
    ax.axis("tight")
    ax.axis("off")
    
    # Banded row colors (shades of green)
    row_colors = [to_rgba("lightgreen", 0.5), to_rgba("white", 1.0)]
    cell_colors = [
        [row_colors[i % 2] for _ in range(len(dataframe.columns))]
        for i in range(len(dataframe) + 1)  # Add 1 for the header row
    ]
    
    # Create the table
    table = ax.table(
        cellText=[dataframe.columns.tolist()] + dataframe.values.tolist(),
        cellColours=cell_colors,
        loc="center",
    )
    
    # Style the header row
    for key, cell in table.get_celld().items():
        if key[0] == 0:  # Header row
            cell.set_text_props(weight="bold", color="white", fontsize = z)
            cell.set_facecolor("darkgreen")
        cell.set_edgecolor("gray")
    
    # Add a title
    ax.set_title(title, fontsize=16, fontweight="bold", color="darkgreen", pad = 1)

# %%
# table for Index per taxonomic category per park

create_banded_table_with_title(park_cat_index_df.reset_index().drop(columns='index'),"Shannon Diversity Index by Park and Taxonomic Category", 12, 4, 10)
plt.savefig("SDIbPTC.jpg")
plt.show()
plt.clf()

# %%
# Table for indices per park

create_banded_table_with_title(park_indices_table, "Shannon Indices by Park", 10, 3, 10)
plt.savefig("Park_Indices.jpg")
plt.show()
plt.clf()

# %%
# graphs for findings 1) Index by park, 2) Averaged Index by Category

fig, axs = plt.subplots(1, 2, figsize=(12, 10))
ax = plt.subplot(1,2,1)
plt.bar(range(len(park_indices)),[x*100 for x in list(park_indices.values())])
ax.set_yscale('log')
ax.set_yticks(range(200, 251, 10))
ax.set_yticklabels(['2.0','2.1','2.2','2.3','2.4','2.5'], fontsize = 7)
ax.set_xticks(range(len(list(park_indices.keys()))))
ax.set_xticklabels(list(park_indices.keys()),rotation = 30, fontsize = 7)
plt.ylabel('Diversity Index (log)')
plt.xlabel('National Park')
plt.title('Shannon Diversity Index \n by National Park')

ax1 = plt.subplot(1,2,2)
plt.bar(range(len(temp)),[x*100 for x in temp], color='green')
ax1.set_yscale('log')
ax1.set_yticks(range(100,131,5))
ax1.set_yticklabels(['1','1.05','1.10','1.15','1.20','1.25','1.30'], fontsize = 7)
ax1.set_xticks(range(len(list(park_cat_index_df['category']))))
ax1.set_xticklabels([x.replace(' ', '\n') for x in list(park_cat_index_df['category'])],rotation = 30, fontsize = 7)
plt.xlabel('Taxonomic Category')
plt.ylabel('Averaged Diversity Index (log)')
plt.title('Average Shannon Diversity Index \n by Taxonomic Category')

plt.savefig("Diversity_Index_Park_Cat.jpg")
plt.show()
plt.clf()

# %%
# Visuals for the appendix with create_banded_table_with_title(df, title, figX, figY, fontsize)

create_banded_table_with_title(obs_df.head(), "Observations", 10, 6, 12)
plt.savefig("obs_df_head.jpg")
plt.show()
plt.clf()

# %%
# Visuals for the appendix with create_banded_table_with_title(df, title, figX, figY, fontsize)

create_banded_table_with_title(spec_df.head(), "Species", 12, 6, 12)
plt.savefig("spec_df_head.jpg")
plt.show()
plt.clf()

# %%
# Visuals for the appendix with create_banded_table_with_title(df, title, figX, figY, fontsize)

create_banded_table_with_title(obs_df.describe(include = "all").reset_index().rename(columns={'index':'measure'}), "Observations Description", 10, 6, 12)
plt.savefig("obs_df_describe.jpg")
plt.show()
plt.clf()

# %%
# Visuals for the appendix with create_banded_table_with_title(df, title, figX, figY, fontsize)

create_banded_table_with_title(spec_df.describe(include = "all").reset_index().rename(columns={'index':'measure'}), "Species Description", 13, 8, 12)
plt.savefig("spec_df_describe.jpg")
plt.show()
plt.clf()

# %%
# Visuals for the appendix. Want to cover bases and also check my own work to see if there is anything that stands out as incorrect. If you see something and this is posted, means I missed it.

num = 0
height = 5
create_banded_table_with_title(merged[merged.park_name == park_l[num]].describe(include = "all").reset_index().rename(columns={'index':'measure'}), "{} Description".format(park_l[num]), 13, height, 12)
plt.savefig("{}.jpg".format(park_l[num]))
plt.show()
plt.clf()

num += 1
create_banded_table_with_title(merged[merged.park_name == park_l[num]].describe(include = "all").reset_index().rename(columns={'index':'measure'}), "{} Description".format(park_l[num]), 13, height, 12)
plt.savefig("{}.jpg".format(park_l[num]))
plt.show()
plt.clf()

num += 1
create_banded_table_with_title(merged[merged.park_name == park_l[num]].describe(include = "all").reset_index().rename(columns={'index':'measure'}), "{} Description".format(park_l[num]), 13, height, 12)
plt.savefig("{}.jpg".format(park_l[num]))
plt.show()
plt.clf()

num += 1
create_banded_table_with_title(merged[merged.park_name == park_l[num]].describe(include = "all").reset_index().rename(columns={'index':'measure'}), "{} Description".format(park_l[num]), 13, height, 12)
plt.savefig("{}.jpg".format(park_l[num]))
plt.show()
plt.clf()
